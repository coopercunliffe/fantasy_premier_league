# %% [markdown]
# Takes the current top 500 players (elements) by total points, sorts by points, and saves them as a csv
#
# Update weekly

# %%
import pandas as pd 
import numpy as np
import requests

# %%
# get the data_static dictionary
url_static = 'https://fantasy.premierleague.com/api/bootstrap-static/'
r_static = requests.get(url_static)
data_static = r_static.json()
elements = data_static['elements']
df = pd.DataFrame(elements)
df = df.set_index('id')

# %%
df = df.drop(486) #cedric transfer to arsenal somehow gave him extra game, screws up everything. so we remove him!

# %%
top500 = df.sort_values(by='total_points', ascending=False).iloc[:450,:]
top500 = top500.rename_axis('id_')
top500.to_csv('top500.csv')

# %%
teams = pd.DataFrame(data_static['teams'])
teams.to_csv('teams')

# %%
top500.head()
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# id_
# 191                         100.0                         100.0  118748
# 215                         100.0                         100.0   61366
# 192                         100.0                         100.0  110979
# 166                         100.0                         100.0  101668
# 182                         100.0                         100.0  169187
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# id_
# 191                  0                       0                  2
# 215                  0                       0                 11
# 192                  0                       0                 10
# 166                  0                       0                  7
# 182                  0                       0                  8
#
#      cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# id_                                                                 ...
# 191                      -2                6             3     0.0  ...
# 215                     -11                6             3     0.0  ...
# 192                     -10                7             3     0.0  ...
# 166                      -7                7             4     0.0  ...
# 182                      -8                6             2     0.0  ...
#
#      threat  ict_index influence_rank influence_rank_type  creativity_rank  \
# id_
# 191  1618.0      308.9              3                   2               17
# 215   745.0      316.0              1                   1                1
# 192   970.0      234.4              7                   3               23
# 166   958.0      199.7              5                   1              139
# 182   353.0      234.5              4                   1                3
#
#     creativity_rank_type threat_rank  threat_rank_type ict_index_rank  \
# id_
# 191                   14           1                 1              2
# 215                    1          28                12              1
# 192                   19          15                 4              8
# 166                   23          18                14             18
# 182                    1          82                 8              7
#
#     ict_index_rank_type
# id_
# 191                   2
# 215                   1
# 192                   5
# 166                   7
# 182                   1
#
# [5 rows x 60 columns]
